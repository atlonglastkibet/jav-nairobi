# %% [markdown]
# # Jav: Initial EDA for GTFS data

# %% [markdown]
# ### a. background

# %% [markdown]
# **What is GTFS?**
# >GTFS (General Transit Feed Specification) is an open, standardized format developed by Google in 2005 for sharing public transit data, including schedules, routes, and geographic information. It's widely used by transit agencies, apps (e.g., Google Maps, Transit), and developers to model bus, rail, ferry, and other services. A GTFS feed is typically a ZIP file containing CSV tables that interconnect via unique IDs, allowing queries like "find all stops on a route" or "get arrival times for a trip."

# %% [markdown]
# **Digital Matatus Dataset**
#
# The Digital Matatus project is an open-source initiative by MIT and local partners that mapped Nairobi's informal matatu (minibus) transit system, collecting data on 135 routes, 4,000+ stops, and schedules. Released as GTFS in 2019, it powers mobile apps, transit maps, and urban mobility research for Kenya's busiest public transport network.
#
# **Source & Download**: [Digital Matatus Official Site](https://digitalmatatus.com/) (GTFS feed available via [OpenAfrica](https://bulk.openafrica.net/id/dataset/gtfs-data-on-public-transport-matatu-routes)).

# %% [markdown]
# ### b. libraries

# %%
import pandas as pd
import numpy as np
import gtfs_kit as gk
import geopandas as gp
from gtfs_kit import cleaners  # for cleaning functions
from gtfs_kit import miscellany  # for quality assessment
import matplotlib.pyplot as plt
import folium  # for interactive maps
from gtfs_kit import routes  # for route-specific functions

# %% [markdown]
# ### c. read GTFS data

# %% [markdown]
# GTFS feed contains the following tables
# 1. agency.txt
# 2. calendar.txt
# 3. calendar_dates.txt
# 4. feed_info.txt
# 5. frequencies.txt
# 6. routes.txt
# 7. shapes.txt
# 8. stop_times.txt
# 9. stops.txt
# 10. trips.txt

# %%
feed_path = '/home/dataopske/Desktop/jav/data/raw/digitalmatatu/GTFS_FEED_2019.zip'
feed = gk.read_feed(feed_path,dist_units='km')

# %% [markdown]
# ### d. validation and cleaning

# %% [markdown]
# step 1: validate GTFS data

# %%
# Assess quality (like validation): Checks for issues like missing shapes or unused stops
quality_results = miscellany.assess_quality(feed)
print("Feed Quality Indicators:")
print(quality_results)  # DataFrame with metrics like 'num_routes', 'num_trips_missing_shapes', etc.

# Clean the feed: Applies ID cleaning, time formatting, route name fixes, and drops zombies
feed = cleaners.clean(feed)  # Comprehensive: Includes drop_zombies internally

# Quick health check (post-cleaning)
print(f"\nFeed validity period: {feed.feed_info.feed_start_date} to {feed.feed_info.feed_end_date}")
print(f"Number of routes: {len(feed.routes)}")
print(f"Number of stops: {len(feed.stops)}")
print(f"Number of trips: {len(feed.trips)}")
# Out:
# Feed Quality Indicators:
#                              indicator                    value
# 0     num_route_short_names_duplicated                        0
# 1    frac_route_short_names_duplicated                      0.0
# 2          num_stop_time_dists_missing                     7533
# 3         frac_stop_time_dists_missing                        1
# 4            num_direction_ids_missing                        0
# 5           frac_direction_ids_missing                      0.0
# 6             num_trips_missing_shapes                        0
# 7            frac_trips_missing_shapes                      0.0
# 8          num_departure_times_missing                        0
# 9         frac_departure_times_missing                      0.0
# 10   num_first_departure_times_missing                        0
# 11  frac_first_departure_times_missing                      0.0
# 12    num_last_departure_times_missing                        0
# 13   frac_last_departure_times_missing                      0.0
# 14                          assessment  probably a fixable feed
#
# Feed validity period: 0    20120302
# Name: feed_start_date, dtype: string to 0    20201231
# Name: feed_end_date, dtype: string
# Number of routes: 136
# Number of stops: 4284
# Number of trips: 272

# %% [markdown]
# step 2: explore the structures and metadata of the GTFS feed

# %%
# Get available tables
tables = [attr for attr in dir(feed) if hasattr(getattr(feed, attr), 'head')]
for table in tables:
    df = getattr(feed, table)
    if df is not None:
        print(f"{table}: {len(df)} rows, {len(df.columns)} columns")
df.head()
# Out:
# agency: 1 rows, 6 columns
# calendar: 1 rows, 10 columns
# calendar_dates: 4 rows, 3 columns
# feed_info: 1 rows, 5 columns
# frequencies: 792 rows, 4 columns
# routes: 136 rows, 5 columns
# shapes: 36483 rows, 4 columns
# stop_times: 7533 rows, 5 columns
# stops: 4284 rows, 6 columns
# trips: 272 rows, 6 columns
#       route_id service_id   trip_id trip_headsign  direction_id  shape_id
# 0  10000107D11      DAILY  1107D110         Ruaka             0  1107D110
# 1  10000107D11      DAILY  1107D111         Ruiru             1  1107D111
# 2  10000114011      DAILY  10114110         Ngara             0  10114110
# 3  10000114011      DAILY  10114111        Limuru             1  10114111
# 4  10000116011      DAILY  10116110          Koja             0  10116110

# %% [markdown]
# step 3. basic descriptive statistics

# %% [markdown]
# a. route overview

# %%
# Merge trips with routes for richer stats
routes_trips = feed.trips.merge(feed.routes[['route_id', 'route_short_name', 'route_type']], on='route_id')
route_stats = routes_trips.groupby('route_short_name').agg({
    'trip_id': 'count',  # Trips per route
    'route_type': 'first'
}).rename(columns={'trip_id': 'num_trips'}).sort_values('num_trips', ascending=False)
route_stats.head(10) # Top 10 busiest routes
# Out:
#                   num_trips  route_type
# route_short_name
# 0027                      2           3
# 0039                      2           3
# 0048                      2           3
# 046P                      2           3
# 1                         2           3
# 10                        2           3
# 100                       2           3
# 100A                      2           3
# 102                       2           3
# 103                       2           3

# %% [markdown]
# b. stop coverage

# %%
print(f"Avg stops per route: {feed.stops.shape[0] / len(feed.routes):.1f}")
# Spatial summary (if GeoPandas works)
print(feed.stops[['stop_lat', 'stop_lon']].describe())
# Out:
# Avg stops per route: 31.5
#           stop_lat     stop_lon
# count  4284.000000  4284.000000
# mean     -1.272630    36.824196
# std       0.058602     0.081633
# min      -1.477218    36.629579
# 25%      -1.303790    36.765932
# 50%      -1.275724    36.827780
# 75%      -1.247147    36.887114
# max      -1.035427    37.076427

# %% [markdown]
# c. schedule basics

# %%
# Service days from calendar
service_days = feed.calendar[['service_id', 'monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday']].sum()
print("Service by day of week:", service_days)
# Out:
# Service by day of week: service_id    DAILY
# monday            1
# tuesday           1
# wednesday         1
# thursday          1
# friday            1
# saturday          1
# sunday            1
# dtype: object

# %% [markdown]
# ### e. table by table EDA

# %% [markdown]
# #### 1. agency

# %% [markdown]
# - basic info on the transit agency(ies) providing service, e.g., agency name, URL, timezone, contact phone. (Usually 1+ rows, one per agency.)

# %%
agency = feed.agency
agency.head()
# Out:
#   agency_id                                        agency_name  \
# 0       UON  Approved SACCOs - University of Nairobi C4D La...
#
#                       agency_url agency_timezone agency_lang   agency_phone
# 0  http://www.digitalmatatus.com  Africa/Nairobi          en  020 - 2729200

# %% [markdown]
# #### 2. calendar

# %% [markdown]
# - Defines service patterns for groups of trips by day-of-week (e.g., monday=1, tuesday=1 for weekdays), plus start/end dates. Used for regularly scheduled services.

# %%
cal = feed.calendar
cal.head()
# Out:
#   service_id  monday  tuesday  wednesday  thursday  friday  saturday  sunday  \
# 0      DAILY       1        1          1         1       1         1       1
#
#   start_date  end_date
# 0   20190101  20201231

# %%
cal.shape
# Out:
# (1, 10)

# %% [markdown]
# #### 3. calendar dates

# %% [markdown]
# - Exceptions to calendar.txt, e.g., added/removed service dates for holidays or events (service_id, date, exception_type=1 for added, 2 for removed).

# %%
cal_dates = feed.calendar_dates
cal_dates
# Out:
#   service_id      date  exception_type
# 0      DAILY  20191020               1
# 1      DAILY  20191212               1
# 2      DAILY  20201020               1
# 3      DAILY  20201212               1

# %%
cal_dates.shape
# Out:
# (4, 3)

# %% [markdown]
# #### 4. feed info

# %% [markdown]
# - Metadata about the entire feed, e.g., feed publisher, version, start/end validity dates, contact email. (Typically 1 row.)

# %%
info = feed.feed_info
info.head()
# Out:
#   feed_publisher_name              feed_publisher_url feed_lang  \
# 0            TRAINING  http://www.digitalmatatus.com/        en
#
#   feed_start_date feed_end_date
# 0        20120302      20201231

# %% [markdown]
# #### 5. frequencies

# %% [markdown]
# - Headways (time intervals) for high-frequency trips without fixed schedules, e.g., every 10 minutes from 7 AM (trip_id, start_time, end_time, headway_secs).

# %%
freqs = feed.frequencies
freqs.head()
# Out:
#     trip_id start_time  end_time  headway_secs
# 0  10106110   06:00:00  09:00:00           300
# 1  10106110   09:00:00  15:00:00           900
# 2  10106110   15:00:00  21:00:00           300
# 3  10106111   06:00:00  09:00:00           300
# 4  10106111   09:00:00  15:00:00           900

# %%
freqs.shape
# Out:
# (792, 4)

# %% [markdown]
# #### 6. routes

# %% [markdown]
# - Details on routes, e.g., route_id, short/long names, type (bus=3, rail=2), agency_id, color. Acts as a high-level grouping for trips.

# %%
routes = feed.routes
routes.head(5)
# Out:
#       route_id agency_id route_short_name                 route_long_name  \
# 0  10000107D11       UON             107D                     Ruaka-Ruiru
# 1  10000114011       UON             114R     Ngara-Rwaka-Ndenderu-Limuru
# 2  10000116011       UON              116        Koja-Ngara-Banana-Limuru
# 3  10100011A11       UON              11A        Odeon-Aga Khan-Highridge
# 4  10200010811       UON              108  UN-New Muthaiga-Gachie-Gichagi
#
#    route_type
# 0           3
# 1           3
# 2           3
# 3           3
# 4           3

# %%
routes
# Out:
#         route_id agency_id route_short_name  \
# 0    10000107D11       UON             107D
# 1    10000114011       UON             114R
# 2    10000116011       UON              116
# 3    10100011A11       UON              11A
# 4    10200010811       UON              108
# ..           ...       ...              ...
# 131  80101048B11       UON              48B
# 132  80200004811       UON              48K
# 133  80200048C11       UON              48C
# 134  80400003011       UON               30
# 135  80500010511       UON              105
#
#                                        route_long_name  route_type
# 0                                          Ruaka-Ruiru           3
# 1                          Ngara-Rwaka-Ndenderu-Limuru           3
# 2                             Koja-Ngara-Banana-Limuru           3
# 3                             Odeon-Aga Khan-Highridge           3
# 4                       UN-New Muthaiga-Gachie-Gichagi           3
# ..                                                 ...         ...
# 131  Odeon-Chiromo-Westlands Bypass-Methodist Guest...           3
# 132           Westlands-ABC Place-Lavington-Kawangware           3
# 133                Odeon-Chiromo-Westlands-ByPass-Yaya           3
# 134                     Odeon-Westlands-Kangemi-Uthiru           3
# 135         Odeon-Westlands-Kangemi-Kinoo-Regen-Kikuyu           3
#
# [136 rows x 5 columns]

# %% [markdown]
# #### 7. shapes

# %% [markdown]
# Geographic paths for routes as sequences of points (shape_id, lat, lon, sequence). Optional; used for mapping curved routes.

# %%
shape = feed.shapes
shape.head()
# Out:
#    shape_id  shape_pt_lat  shape_pt_lon  shape_pt_sequence
# 0  10106110     -1.173842     36.758779                  1
# 1  10106110     -1.174523     36.759025                  2
# 2  10106110     -1.175076     36.759267                  3
# 3  10106110     -1.175821     36.759535                  4
# 4  10106110     -1.176998     36.759982                  5

# %%
shape.shape
# Out:
# (36483, 4)

# %% [markdown]
# #### 8. stops

# %% [markdown]
# - Stop locations: stop_id, name, lat/lon, platform code, parent station (for grouped stops like platforms). Forms the network of points.

# %%
stops = feed.stops
stops.head(5)
# Out:
#    stop_id           stop_name  stop_lat   stop_lon  location_type  \
# 0  0001RLW            Railways -1.290884  36.828242              0
# 1  0002KOJ                Koja -1.281230  36.822596              1
# 2  0003NGR               Ngara -1.274395  36.823806              1
# 3  0004ODN               Odeon -1.282769  36.825032              1
# 4  0005AMB  Kencom/Ambassadeur -1.285963  36.826048              1
#
#   parent_station
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
stops.shape
# Out:
# (4284, 6)

# %%
stops['stop_name'].value_counts()
# Out:
# stop_name
# Tuskys                       23
# Car Wash                     22
# Naivas                       21
# Kwa Chief                    19
# Equity                       17
#                              ..
# Stima Sacco                   1
# Mothers Mercys/GD             1
# Mifereji/God's Ability        1
# Donholm Interchange/Stage     1
# Kwa D.O                       1
# Name: count, Length: 2474, dtype: Int64

# %%
stops['stop_name'].nunique()
# Out:
# 2474

# %% [markdown]
# #### 9. stop times

# %% [markdown]
# - Timetables for trips: arrival/departure times, stop sequences, distances (trip_id, stop_id, arrival_time, departure_time, stop_sequence). Core table for schedules.

# %%
stop_time = feed.stop_times
stop_time.head()
# Out:
#     trip_id arrival_time departure_time  stop_id  stop_sequence
# 0  10106110     06:00:00       06:00:20  0110BAA              1
# 1  10106110     06:00:34       06:00:54  0110BNI              2
# 2  10106110     06:01:10       06:01:30  0110UMK              3
# 3  10106110     06:01:49       06:02:09  0110AEA              4
# 4  10106110     06:02:45       06:03:05  0100MOM              5

# %% [markdown]
# #### 10. trips

# %% [markdown]
# - Individual vehicle runs: trip_id, route_id, service_id (links to calendar), headsign (destination), shape_id, wheelchair_accessible. Bridges routes to stop_times.

# %%
trips = feed.trips
trips.head()
# Out:
#       route_id service_id   trip_id trip_headsign  direction_id  shape_id
# 0  10000107D11      DAILY  1107D110         Ruaka             0  1107D110
# 1  10000107D11      DAILY  1107D111         Ruiru             1  1107D111
# 2  10000114011      DAILY  10114110         Ngara             0  10114110
# 3  10000114011      DAILY  10114111        Limuru             1  10114111
# 4  10000116011      DAILY  10116110          Koja             0  10116110

# %%
info.shape
# Out:
# (1, 5)

# %% [markdown]
# ### f. visualizations

# %% [markdown]
# #### a. stop maps

# %%
import folium
from IPython.display import display

# Center map around average stop coordinates
m = folium.Map(
    location=[feed.stops.stop_lat.mean(), feed.stops.stop_lon.mean()],
    zoom_start=11,
    tiles='cartodb positron'  # clean basemap
)

# Add first 100 stops for visualization
for _, row in feed.stops.head(100).iterrows():
    folium.CircleMarker(
        location=[row.stop_lat, row.stop_lon],
        radius=3,
        popup=row.stop_name,
        color='blue',
        fill=True,
        fill_opacity=0.7
    ).add_to(m)

# Display inline in Jupyter
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86be8c95c009a0f4e063c0831aa102fe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86be8c95c009a0f4e063c0831aa102fe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86be8c95c009a0f4e063c0831aa102fe = L.map(
#                 &quot;map_86be8c95c009a0f4e063c0831aa102fe&quot;,
#                 {
#                     center: [-1.2726302472398592, 36.824195880228004],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_351975a9530ea8aa59b5bbed965c83de = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_351975a9530ea8aa59b5bbed965c83de.addTo(map_86be8c95c009a0f4e063c0831aa102fe);
#
#
#             var circle_marker_1000d4e4e0726eff3e993b508d0bbaae = L.circleMarker(
#                 [-1.290884, 36.828242],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_86be8c95c009a0f4e063c0831aa102fe);
#
#
#         var popup_5826246e6e63086b59db237c670fc37f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8811c87b17bc2ad4a57b6fc0175d641c = $(`&lt;div id=&quot;html_8811c87b17bc2ad4a57b6fc0175d641c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Railways&lt;/div&gt;`)[0];
#                 popup_5826246e6e63086b59db237c670fc37f.setContent(html_8811c87b17bc2ad4a57b6fc0175d641c);
#
#
#
#         circle_marker_1000d4e4e0726eff3e993b508d0bbaae.bindPopup(popup_5826246e6e63086b59db237c670fc37f)
#         ;
#
#
#
#
#             var circle_marker_3a20ab6b9911510487da1603ba5ac6c3 = L.circleMarker(
#                 [-1.28123, 36.822596],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_86be8c95c009a0f4e063c0831aa102fe);
#
#
#         var popup_f53d43ed8ddcc3fb829d0cd95e22ee94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a108ceac24e3b71da8a407636151eb9c = $(`&lt;div id=&quot;html_a108ceac24e3b71da8a407636151eb9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Koja&lt;/div&gt;`)[0];
#                 popup_f53d43ed8ddcc3fb829d0cd95e22ee94.setContent(html_a108ceac24e3b71da8a407636151eb9c);
#
#
#
#         circle_marker_3a20ab6b9911510487da1603ba5ac6c3.bindPopup(popup_f53d43ed8ddcc3fb829d0cd95e22ee94)
#         ;
#
#
#
#
#             var circle_marker_7c742279cccb44eeb4321f112e12d218 = L.circleMarker(
#                 [-1.274395, 36.823806],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_86be8c95c009a0f4e063c0831aa102fe);
#
#
#         var popup_b66cb7f2c6ee8f8de6c8e5c48ad03270 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86e9c15f4cd7143502893976547ffd4a = $(`&lt;div id=&quot;html_86e9c15f4cd7143502893976547ffd4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ngara&lt;/div&gt;`)[0];
#                 popup_b66cb7f2c6ee8f8de6c8e5c48ad03270.setContent(html_86e9c15f4cd7143502893976547ffd4a);
#
#
#
#         circle_marker_7c742279cccb44eeb4321f112e12d218.bindPopup(popup_b66cb7f2c6ee8f8de6c8e5c48ad03270)

# %% [markdown]
# #### b. route lengths

# %%
# import pandas as pd

# start, end = pd.to_datetime(date_range[0]), pd.to_datetime(date_range[1])
# dates = pd.date_range(start, end, freq='7D')  # every 7 days

# stats_all = [gk.compute_route_stats(feed, date=d) for d in dates]
# stats = pd.concat(stats_all)

# %%
# Select one route
sample_route = feed.routes.route_short_name.iloc[0]

# Filter trips for that route
route_trips = feed.trips[
    feed.trips.route_id == feed.routes[feed.routes.route_short_name == sample_route].route_id.iloc[0]
]

# Get stop_times for those trips
sample_stop_times = feed.stop_times[
    feed.stop_times.trip_id.isin(route_trips.trip_id)
].copy()

# Extract hour from arrival_time safely
sample_stop_times['arrival_hour'] = pd.to_datetime(
    sample_stop_times['arrival_time'],
    format='%H:%M:%S',
    errors='coerce'
).dt.hour

# Plot histogram
sample_stop_times['arrival_hour'].hist(bins=24)
plt.title(f"Arrival Hour Distribution — Route {sample_route}")
plt.xlabel("Hour of Day")
plt.ylabel("Frequency")
plt.show()

# %%
# Pick a route_id
sample_route_id = feed.routes.route_id.iloc[0]
route_trips = feed.trips[feed.trips.route_id == sample_route_id].trip_id.unique()[:5]  # Sample trips
path = feed.stop_times[feed.stop_times.trip_id.isin(route_trips)].merge(
    feed.stops[['stop_id', 'stop_name', 'stop_lat', 'stop_lon']], on='stop_id'
).sort_values(['trip_id', 'stop_sequence'])
path.head(20)  # Sequence of stops with times/locations
# Out:
#      trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 0   1107D110     06:00:00       06:00:20  0213MRY              1
# 1   1107D110     06:02:39       06:02:59  0100OOA              2
# 2   1107D110     06:03:26       06:03:46  0100AWA              3
# 3   1107D110     06:04:18       06:04:38  0100TPS              4
# 4   1107D110     06:05:25       06:05:45  0100OTN              5
# 5   1107D110     06:06:57       06:07:17  0110LHL              6
# 6   1107D110     06:08:43       06:09:03  0110AOH              7
# 7   1107D110     06:09:33       06:09:53  0110ISR              8
# 8   1107D110     06:11:59       06:12:19  0100RJI              9
# 9   1107D110     06:12:40       06:13:00  0100JO.             10
# 10  1107D110     06:14:26       06:14:46  0100NRP             11
# 11  1107D110     06:16:12       06:16:32  0100AEL             12
# 12  1107D110     06:18:20       06:18:40  0100..M             13
# 13  1107D110     06:19:46       06:20:06  0100ANJ             14
# 14  1107D110     06:21:53       06:22:13  0100A.P             15
# 15  1107D110     06:23:52       06:24:12  0100ACP             16
# 16  1107D110     06:24:46       06:25:06  0100KHR             17
# 17  1107D110     06:26:11       06:26:31  0100PSA             18
# 18  1107D110     06:27:25       06:27:45  0110WOJ             19
# 19  1107D110     06:28:23       06:28:43  010044G             20
#
#                      stop_name  stop_lat   stop_lon
# 0                        Ruiru -1.147669  36.959317
# 1                     Kwa Soko -1.149789  36.948829
# 2                     Wataalam -1.149612  36.947408
# 3                         Post -1.149687  36.945525
# 4                       Hilton -1.150637  36.942590
# 5           Full Gospel Church -1.151018  36.937462
# 6                    Mama Shop -1.151753  36.931196
# 7                Ruiru Prisons -1.151871  36.929525
# 8          Ruiru Road Junction -1.152105  36.919942
# 9                          O.J -1.152971  36.920232
# 10  Round About Eastern Bypass -1.155235  36.926119
# 11               Membley Stage -1.160297  36.922367
# 12                        K.M. -1.167727  36.919008
# 13                 Kwa Kiwanja -1.171676  36.916509
# 14                        A.P. -1.178289  36.911960
# 15                        PCEA -1.184213  36.907515
# 16  Kahawa Railways Roundabout -1.186098  36.906817
# 17           La Philla Carwash -1.190634  36.906088
# 18             Maziwa Junction -1.193992  36.904538
# 19                 44 Githurai -1.195514  36.902695

# %%
import folium
from gtfs_kit import routes

# Get all short names of routes
all_short_names = feed.routes['route_short_name'].dropna().tolist()

# Plot routes using gtfs_kit
m = routes.map_routes(feed, route_short_names=all_short_names)

# Manually overlay stops
for _, row in feed.stops.iterrows():
    folium.CircleMarker(
        location=[row.stop_lat, row.stop_lon],
        radius=2,
        color="blue",
        fill=True,
        fill_opacity=0.6
    ).add_to(m)

# Display interactively in notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7967163a2e20286cd621e2c1603a739e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7967163a2e20286cd621e2c1603a739e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7967163a2e20286cd621e2c1603a739e = L.map(
#                 &quot;map_7967163a2e20286cd621e2c1603a739e&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: true,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a171c1569b8099c3ac0c023b4a2d0d7a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a171c1569b8099c3ac0c023b4a2d0d7a.addTo(map_7967163a2e20286cd621e2c1603a739e);
#
#
#             var feature_group_cc259c755fbd033152ed75d97caa4f34 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_43de28e2f62d9e001ff99b80dfe87d55_styler(feature) {
#             switch(feature.properties.route_id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#66c2a5&quot;};
#             }
#         }
#
#         function geo_json_43de28e2f62d9e001ff99b80dfe87d55_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_43de28e2f62d9e001ff99b80dfe87d55 = L.geoJson(null, {
#                 onEachFeature: geo_json_43de28e2f62d9e001ff99b80dfe87d55_onEachFeature,
#
#                 style: geo_json_43de28e2f62d9e001ff99b80dfe87d55_styler,
#             ...{
# }
#         });
#
#         function geo_json_43de28e2f62d9e001ff99b80dfe87d55_add (data) {
#             geo_json_43de28e2f62d9e001ff99b80dfe87d55
#                 .addData(data);
#         }
#             geo_json_43de28e2f62d9e001ff99b80dfe87d55_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[36.9593381882, -1.1475455761], [36.9594722986, -1.1475777626], [36.9595366716, -1.14784598351], [36.9591718912, -1.14794790745], [36.9592899084, -1.14837706089], [36.960327, -1.148151], [36.960423, -1.148097], [36.960537, -1.148134], [36.96059, -1.148229], [36.960567, -1.148336], [36.960464, -1.148395], [36.960365, -1.148371], [36.958633, -1.148734], [36.957706, -1.148662], [36.9512915611, -1.14993810654], [36.950712204, -1.1499273777], [36.9492208958, -1.14972352982], [36.947439909, -1.14951968193], [36.946667, -1.149425], [36.946251, -1.14943], [36.9455516338, -1.14962697029], [36.9425904751, -1.15061402321], [36.941582, -1.150869], [36.9374406338, -1.15102171898], [36.9353699684, -1.15110754967], [36.9315290451, -1.1516225338], [36.930295229, -1.15180492401], [36.9292974472, -1.15182638168], [36.9278597832, -1.15167617798], [36.926625967, -1.15140795708], [36.92363, -1.150674], [36.923218, -1.15066], [36.922935, -1.150721], [36.919857, -1.15215], [36.919975, -1.152559], [36.920116, -1.152823], [36.9202208519, -1.15294754505], [36.920574, -1.153165], [36.92609, -1.154922], [36.926189, -1.154798], [36.9263792038, -1.15478754044], [36.926487, -1.15488], [36.9265079498, -1.15505576134], [36.926357, -1.155197], [36.926163, -1.155159], [36.923309, -1.158797], [36.9227206707, -1.15960478783], [36.922527, -1.159979], [36.9223988056, -1.16023778915], [36.9217550755, -1.1614716053], [36.9207036495, -1.16389095783], [36.9196522236, -1.16637468338], [36.9193571806, -1.16707742214], [36.9189977646, -1.16784453392], [36.9186061621, -1.16853654385], [36.9176888466, -1.16999566555], [36.9165247679, -1.17168009281], [36.9123351574, -1.17772579193], [36.9119650126, -1.17827832699], [36.9114071131, -1.17901861668], [36.9102537632, -1.18044018745], [36.908825, -1.182092], [36.9082581997, -1.18287563324], [36.907768, -1.183703], [36.9074910879, -1.18418455124], [36.907238, -1.184769], [36.9070726633, -1.18526279926], [36.9070190191, -1.18553102016], [36.9070672989, -1.18571341038], [36.907094121, -1.18583142757], [36.907029748, -1.18597626686], [36.9069170952, -1.18603527546], [36.906734705, -1.18602454662], [36.906677, -1.18645], [36.906439662, -1.187505126], [36.906208992, -1.18958115578], [36.9061714411, -1.18991374969], [36.906080246, -1.19058966637], [36.9057905674, -1.19153916836], [36.9054794312, -1.19234383106], [36.9051629305, -1.19297146797], [36.9045943022, -1.19391560555], [36.904045, -1.194468], [36.903553, -1.194895], [36.9031727314, -1.1951816082], [36.9025611877, -1.19560539722], [36.898308, -1.197921], [36.8942570686, -1.20044946671], [36.8901157379, -1.20275616646], [36.8747520447, -1.21102809906], [36.8742853403, -1.21128022671], [3

# %%
import folium
from gtfs_kit import routes

# Get all short names of routes
all_short_names = feed.routes['route_short_name'].dropna().tolist()

# Plot routes using gtfs_kit
m = routes.map_routes(feed, route_short_names=all_short_names)

# Display interactively in the notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_66f9798032dafcb61be924925163cb8d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_66f9798032dafcb61be924925163cb8d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_66f9798032dafcb61be924925163cb8d = L.map(
#                 &quot;map_66f9798032dafcb61be924925163cb8d&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: true,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cdf5f74b9a736dc9ed3e190f9b93367a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cdf5f74b9a736dc9ed3e190f9b93367a.addTo(map_66f9798032dafcb61be924925163cb8d);
#
#
#             var feature_group_957f5ee9528093f988573b58426263df = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_e9685c8f349b62a1681e3dd1ae07a4c1_styler(feature) {
#             switch(feature.properties.route_id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#66c2a5&quot;};
#             }
#         }
#
#         function geo_json_e9685c8f349b62a1681e3dd1ae07a4c1_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_e9685c8f349b62a1681e3dd1ae07a4c1 = L.geoJson(null, {
#                 onEachFeature: geo_json_e9685c8f349b62a1681e3dd1ae07a4c1_onEachFeature,
#
#                 style: geo_json_e9685c8f349b62a1681e3dd1ae07a4c1_styler,
#             ...{
# }
#         });
#
#         function geo_json_e9685c8f349b62a1681e3dd1ae07a4c1_add (data) {
#             geo_json_e9685c8f349b62a1681e3dd1ae07a4c1
#                 .addData(data);
#         }
#             geo_json_e9685c8f349b62a1681e3dd1ae07a4c1_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[36.9593381882, -1.1475455761], [36.9594722986, -1.1475777626], [36.9595366716, -1.14784598351], [36.9591718912, -1.14794790745], [36.9592899084, -1.14837706089], [36.960327, -1.148151], [36.960423, -1.148097], [36.960537, -1.148134], [36.96059, -1.148229], [36.960567, -1.148336], [36.960464, -1.148395], [36.960365, -1.148371], [36.958633, -1.148734], [36.957706, -1.148662], [36.9512915611, -1.14993810654], [36.950712204, -1.1499273777], [36.9492208958, -1.14972352982], [36.947439909, -1.14951968193], [36.946667, -1.149425], [36.946251, -1.14943], [36.9455516338, -1.14962697029], [36.9425904751, -1.15061402321], [36.941582, -1.150869], [36.9374406338, -1.15102171898], [36.9353699684, -1.15110754967], [36.9315290451, -1.1516225338], [36.930295229, -1.15180492401], [36.9292974472, -1.15182638168], [36.9278597832, -1.15167617798], [36.926625967, -1.15140795708], [36.92363, -1.150674], [36.923218, -1.15066], [36.922935, -1.150721], [36.919857, -1.15215], [36.919975, -1.152559], [36.920116, -1.152823], [36.9202208519, -1.15294754505], [36.920574, -1.153165], [36.92609, -1.154922], [36.926189, -1.154798], [36.9263792038, -1.15478754044], [36.926487, -1.15488], [36.9265079498, -1.15505576134], [36.926357, -1.155197], [36.926163, -1.155159], [36.923309, -1.158797], [36.9227206707, -1.15960478783], [36.922527, -1.159979], [36.9223988056, -1.16023778915], [36.9217550755, -1.1614716053], [36.9207036495, -1.16389095783], [36.9196522236, -1.16637468338], [36.9193571806, -1.16707742214], [36.9189977646, -1.16784453392], [36.9186061621, -1.16853654385], [36.9176888466, -1.16999566555], [36.9165247679, -1.17168009281], [36.9123351574, -1.17772579193], [36.9119650126, -1.17827832699], [36.9114071131, -1.17901861668], [36.9102537632, -1.18044018745], [36.908825, -1.182092], [36.9082581997, -1.18287563324], [36.907768, -1.183703], [36.9074910879, -1.18418455124], [36.907238, -1.184769], [36.9070726633, -1.18526279926], [36.9070190191, -1.18553102016], [36.9070672989, -1.18571341038], [36.907094121, -1.18583142757], [36.907029748, -1.18597626686], [36.9069170952, -1.18603527546], [36.906734705, -1.18602454662], [36.906677, -1.18645], [36.906439662, -1.187505126], [36.906208992, -1.18958115578], [36.9061714411, -1.18991374969], [36.906080246, -1.19058966637], [36.9057905674, -1.19153916836], [36.9054794312, -1.19234383106], [36.9051629305, -1.19297146797], [36.9045943022, -1.19391560555], [36.904045, -1.194468], [36.903553, -1.194895], [36.9031727314, -1.1951816082], [36.9025611877, -1.19560539722], [36.898308, -1.197921], [36.8942570686, -1.20044946671], [36.8901157379, -1.20275616646], [36.8747520447, -1.21102809906], [36.8742853403, -1.21128022671], [3
